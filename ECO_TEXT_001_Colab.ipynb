# %% [markdown]
# # ECO TEXT 001 — Medição Espectral Multi-Escala em Texto
# **Manifesto AlphaPhi · Vitor Edson Delavi · 2026**
#
# Mede estrutura espectral em 4 escalas (palavra → frase → parágrafo → texto)
# e busca o atrator φ — equivalente do α*=1/3 encontrado no ECO BEEP 880.
#
# **Protocolo de integridade:**
# - Seed gerada por timestamp — nenhum valor escolhido pelo pesquisador
# - φ aparece apenas na partição espectral — nunca como parâmetro de teste
# - Resultados reportados na íntegra

# %%
# Célula 1 — Instalar dependências
# !pip install sentence-transformers -q

# %%
# Célula 2 — Clonar repositório e carregar corpus
# !git clone https://github.com/vitoredsonalphaphi/alpha_phi_manifesto.git
# %cd alpha_phi_manifesto

# %%
# Célula 3 — Rodar experimento no corpus da Invocação Rosacruz
# !python eco_text_001.py corpus_invocacao_rosacruz.txt

# %% [markdown]
# ---
# ## Rodar em outro texto
#
# Para testar qualquer outro corpus `.txt`, suba o arquivo no Colab e rode:
#
# ```python
# !python eco_text_001.py seu_texto.txt
# ```
#
# Ou cole o texto diretamente na célula abaixo:

# %%
# Célula 4 — Colar texto diretamente (opcional)
texto = """
Cole aqui qualquer texto para medir.
"""

with open('corpus_custom.txt', 'w', encoding='utf-8') as f:
    f.write(texto)

# !python eco_text_001.py corpus_custom.txt
